# %% [markdown]
# <a href="https://colab.research.google.com/github/jrebull/Vision/blob/main/MNA_Vision_Team13_2_5_Algoritmos_x_Pixeles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### GitHub Link: https://github.com/jrebull/Vision/blob/main/MNA_Vision_Team13_2_5_Algoritmos_x_Pixeles.ipynb

# %% [markdown]
# # 🎓 Maestría en Inteligencia Artificial Aplicada
#
# <center>
#
# [![Institution](https://img.shields.io/badge/Institution-Tecnológico%20de%20Monterrey-1F497D?style=for-the-badge&logo=graduation-cap)](https://tec.mx)
# [![Course](https://img.shields.io/badge/Course-Computer%20Vision-FF6B6B?style=for-the-badge&logo=eye)](https://tec.mx)
# [![Activity](https://img.shields.io/badge/Activity%202.5-Google%20Colab-F9AB00?style=for-the-badge&logo=googlecolab)](https://colab.research.google.com)
#
# </center>
#
# ---
#
# ## 🖼️ **Visión Computacional para Imágenes y Video**
#
# ### 👨‍🏫 **Profesores**
# - **Profesor Titular:** Dr. Gilberto Ochoa Ruiz
# - **Profesor Asistente:** MIP Ma. del Refugio Melendez Alfaro
#
# ---
#
# ## 📊 **Actividad: Algoritmos de Mejoramiento de Imágenes Basado por Píxeles**
#
# ### 📌 **Detalles de la Actividad**
# - **Código:** 2.5 Google Colab
# - **Título:** Algoritmos de mejoramiento de imágenes basado por píxeles
# - **Fecha de entrega:** 📅 Septiembre 21, 2025 a las 23:59
# - **Puntos:** 5 puntos
# - **Formato de entrega:** PDF y ZIP
#
# ---
#
# ## 👥 **Team 13**
#
# ### 🚀 **Nuestro Equipo**
#
# <table style="width:100%; border:none;">
# <tr>
# <td style="text-align:center; border:none; padding:20px;">
#
# ### **Javier Augusto Rebull Saucedo**
# <img src="https://iili.io/KuvsGKx.png" alt="Javier Augusto Rebull Saucedo" width="150">
#
# **Matrícula:** `A01795838`
# 🎓 MNA Student
#
# </td>
# <td style="text-align:center; border:none; padding:20px;">
#
# ### **Juan Carlos Pérez Nava**
# <img src="https://iili.io/KuvP4gp.png" alt="Juan Carlos Pérez Nava" width="150">
#
# **Matrícula:** `A01795941`
# 🎓 MNA Student
#
# </td>
# </tr>
# <tr>
# <td style="text-align:center; border:none; padding:20px;">
#
# ### **Luis Gerardo Sánchez Salazar**
# <img src="https://iili.io/KuvLaJp.png" alt="Luis Gerardo Sánchez Salazar" width="150">
#
# **Matrícula:** `A01232963`
# 🎓 MNA Student
#
# </td>
# <td style="text-align:center; border:none; padding:20px;">
#
# ### **Oscar Enrique García García**
# <img src="https://iili.io/KuvQx24.png" alt="Oscar Enrique García García" width="150">
#
# **Matrícula:** `A01016093`
# 🎓 MNA Student
#
# </td>
# </tr>
# </table>
#
# > *"Trabajando juntos para explorar las fronteras de la visión computacional"* 🚀
#
# ---
#
# ## 🎯 **Objetivos del Proyecto**
#
# En esta sesión profundizaremos en el estudio de las **técnicas de mejoramiento de imágenes píxel a píxel** usando ecualización de histogramas, abordando técnicas complementarias al uso de histogramas globales, tales como el uso de **ventanas deslizantes** o **mosaicos**. Además, discutiremos las métricas usadas para comparar diferentes métodos de mejoramiento de imágenes. Los temas discutidos de forma teórica serán abordados aquí de forma práctica usando Google Colab.
#
# ---
#
# ## 📋 **Ejercicios a Implementar**
#
# ### **1️⃣ Tile-Based Histogram Equalization**
#
# **Investigar e implementar** el método de ecualización de histogramas basado en mosaicos. En este método:
#
# - La imagen se particiona en diferentes ventanas (mosaicos)
# - Los histogramas se calculan de forma independiente
# - La corrección se aplica sobre cada ventana
# - Variar el tamaño de la ventana y analizar resultados
# - Proponer soluciones para las diferencias de contraste entre bloques
#
# ### **2️⃣ Sliding Window Adaptive Histogram Equalization (SWAHE)**
#
# **Investigar e implementar** un método sencillo de SWAHE:
#
# - Implementar ventana deslizante adaptativa
# - Comparar con diferentes tipos de imágenes
# - Analizar ventajas y desventajas del método
#
# ### **3️⃣ CLAHE (Contrast Limited Adaptive Histogram Equalization)**
#
# **Investigar e implementar** el algoritmo CLAHE:
#
# - Puede usar la implementación de OpenCV
# - Probar sobre diferentes tipos de imágenes
# - Comparar con el método de ecualización básico
# - Proveer una descripción detallada del método basada en investigación bibliográfica
#
# ---
#
# ## 🛠️ **Tecnologías y Bibliotecas Utilizadas**
#
# | Biblioteca | Descripción | Logo |
# |------------|-------------|------|
# | **Python** | Lenguaje de programación principal | ![Python](https://img.shields.io/badge/Python-3776AB?style=flat&logo=python&logoColor=white) |
# | **OpenCV** | Visión computacional | ![OpenCV](https://img.shields.io/badge/OpenCV-5C3EE8?style=flat&logo=opencv&logoColor=white) |
# | **NumPy** | Computación numérica | ![NumPy](https://img.shields.io/badge/NumPy-013243?style=flat&logo=numpy&logoColor=white) |
# | **Matplotlib** | Visualización de datos | ![Matplotlib](https://img.shields.io/badge/Matplotlib-3776AB?style=flat&logo=python&logoColor=white) |
# | **PIL/Pillow** | Procesamiento de imágenes | ![PIL](https://img.shields.io/badge/Pillow-3776AB?style=flat&logo=python&logoColor=white) |
# | **Scikit-image** | Procesamiento de imágenes científico | ![Scikit](https://img.shields.io/badge/Scikit--image-F7931E?style=flat&logo=scikit-learn&logoColor=white) |
# | **SciPy** | Computación científica | ![SciPy](https://img.shields.io/badge/SciPy-8CAAE6?style=flat&logo=scipy&logoColor=white) |
#
# ---
#
# ## 🔧 **Referencia Rápida de Funciones Clave**
#
# ### **PIL (Python Imaging Library)**
# ```python
# from PIL import Image, ImageOps
#
# # Cargar imágenes
# img = Image.open('imagen.jpg')
#
# # Ecualización de histogramas
# img_eq = ImageOps.equalize(img)
# ```
#
# ### **OpenCV (cv2)**
# ```python
# import cv2
#
# # Ecualización de histogramas global
# img_eq = cv2.equalizeHist(img_gray)
#
# # Crear objeto CLAHE
# clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
# img_clahe = clahe.apply(img_gray)
#
# # Conversión de espacios de color
# img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ```
#
# ### **Scikit-image**
# ```python
# from skimage import exposure
#
# # Ecualización de histogramas
# img_eq = exposure.equalize_hist(img)
#
# # CLAHE implementation
# img_adapteq = exposure.equalize_adapthist(img, clip_limit=0.03)
#
# # Calcular histogramas
# hist, bins = exposure.histogram(img)
# ```
#
# ### **SciPy**
# ```python
# from scipy.ndimage import gaussian_filter, median_filter
#
# # Filtro gaussiano para suavizado
# img_smooth = gaussian_filter(img, sigma=1)
#
# # Filtro de mediana para reducción de ruido
# img_median = median_filter(img, size=3)
# ```
#
# ---
#
# ## 🔑 **Conceptos Clave a Explorar**
#
# | Concepto | Descripción |
# |----------|-------------|
# | **📊 Histogramas** | Distribución de intensidades de píxeles |
# | **🎯 Ecualización** | Mejora del contraste global |
# | **🪟 Ventanas Deslizantes** | Procesamiento local adaptativo |
# | **📐 Métricas** | Evaluación cuantitativa |
#
# ---
#
# ## 📚 **Recursos Adicionales**
#
# ### **Documentación Oficial**
# - 📖 [OpenCV Documentation](https://docs.opencv.org/)
# - 📖 [Scikit-image User Guide](https://scikit-image.org/docs/stable/)
# - 📖 [PIL/Pillow Documentation](https://pillow.readthedocs.io/)
#
# ### **Tutoriales Recomendados**
# - 🎥 [Image Enhancement Techniques](https://www.youtube.com/results?search_query=image+enhancement+opencv)
# - 📝 [CLAHE Explained](https://docs.opencv.org/master/d5/daf/tutorial_py_histogram_equalization.html)
# - 💻 [Adaptive Histogram Equalization](https://en.wikipedia.org/wiki/Adaptive_histogram_equalization)
#
# ---
#
# <center>
#
# ## **¡Exploremos el mejoramiento de imágenes píxel a píxel! 🚀**
#
# ### **Team 13 - Computer Vision 2025**
#
# ---
#
# [![Made with](https://img.shields.io/badge/Made%20with-❤️-red?style=flat-square)](https://tec.mx)
# [![Python](https://img.shields.io/badge/Python-3.x-blue?style=flat-square&logo=python)](https://python.org)
# [![OpenCV](https://img.shields.io/badge/OpenCV-4.x-green?style=flat-square&logo=opencv)](https://opencv.org)
#
# </center>
#
# ---
#
# 📝 **Nota:** Este documento fue creado para la Actividad 2.5 del curso de Computer Vision
# Maestría en Inteligencia Artificial Aplicada - Tecnológico de Monterrey
# *Última actualización: Septiembre 14 2025*

# %% [markdown]
# # 2. Image Enhancement
#
# ## Table of Contents
# 1. [Libraries](#libraries)
# 2. [Histogram Equalization](#hist)
# 3. [Denoising with Filters](#denoising)
# 4. [Challenge](#challenge)

# %% [markdown]
# ## Importing Libraries <a class="anchor" id="libraries" ></a>

# %%
import gdown
from google.colab import drive
import os
from PIL.ExifTags import TAGS

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from skimage import exposure
import skimage
from scipy.ndimage.filters import gaussian_filter as gauss
from scipy.ndimage.filters import median_filter as med
import cv2
# Out:
# /tmp/ipython-input-3972790099.py:7: DeprecationWarning: Please import `gaussian_filter` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import gaussian_filter as gauss
# /tmp/ipython-input-3972790099.py:8: DeprecationWarning: Please import `median_filter` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import median_filter as med

# %% [markdown]
# ### Drive con las imagenes: https://drive.google.com/drive/folders/1jdidAbt77LG2rSDdPrjCqdf0mW20vSZa?usp=sharing

# %%
# Monta Google Drive
drive.mount('/content/drive')

# Definimos la ruta en Drive
ruta_drive = '/content/drive/MyDrive/MNA_Vision/2.5_Algoritmos_Pixeles'
os.makedirs(ruta_drive, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# --- Descarga de Imágenes ---

# 1. Descarga de Brockton MA.JPG
id_brockton = '1WHFJdcZO0_HfUiU9TV1VXoY3iYaMiYo9'
output_brockton = '2017_Brockton_Massachusetts'
gdown.download(id=id_brockton, output=output_brockton, quiet=True)


print("✅ Descargas completadas")
# Out:
# ✅ Descargas completadas

# %% [markdown]
# #I## Informacion de Metadatos de la Imagen

# %%
from PIL import Image
from PIL.ExifTags import TAGS
from tabulate import tabulate
import textwrap

def display_exif_tabulate(image_path):
    img_pil = Image.open(image_path)
    exif_data = img_pil._getexif()

    if not exif_data:
        print("No se encontraron datos EXIF")
        return

    # Preparar datos para la tabla
    table_data = []
    for tag_id, value in exif_data.items():
        tag = TAGS.get(tag_id, tag_id)

        # Limitar longitud de valores muy largos
        value_str = str(value)
        if len(value_str) > 50:
            value_str = textwrap.fill(value_str, width=50)

        # Agregar emojis para ciertas categorías
        emoji = ""
        if 'Date' in tag:
            emoji = "📅"
        elif 'GPS' in tag:
            emoji = "📍"
        elif tag in ['Make', 'Model']:
            emoji = "📷"
        elif tag in ['ISO', 'ExposureTime', 'FNumber']:
            emoji = "⚙️"

        table_data.append([f"{emoji} {tag}", value_str])

    # Mostrar tabla
    print("\n" + "="*60)
    print("📸 DATOS EXIF DE LA IMAGEN 📸".center(60))
    print("="*60 + "\n")

    print(tabulate(table_data,
                   headers=['Propiedad', 'Valor'],
                   tablefmt='fancy_grid',
                   colalign=('left', 'left')))

# Usar:
display_exif_tabulate('2017_Brockton_Massachusetts')
# Out:
# ...
#                 📸 DATOS EXIF DE LA IMAGEN 📸
# ...
#
# ╒═════════════════════════╤════════════════════════════════════════════════════╕
# │ Propiedad               │ Valor                                              │
# ╞═════════════════════════╪════════════════════════════════════════════════════╡
# │ 📍 GPSInfo              │ {1: 'N', 2: (42.0, 6.0, 8.01), 3: 'W', 4: (71.0,   │
# │                         │ 2.0, 33.62), 5: b'\x00', 6: 51.353191489361706, 7: │
# │                         │ (23.0, 51.0, 6.0), 12: 'K', 13:                    │
# │                         │ 0.015291943322609351, 16: 'T', 17:                 │
# │                         │ 298.5287356321839, 23: 'T', 24: 298.5287356321839, │
# │                         │ 29: '2017:06:13', 31: 6.0}                         │
# ├─────────────────────────┼────────────────────────────────────────────────────┤
# │ ResolutionUnit          │ 2                                                  │
# ...

# %% [markdown]
# # Inicio de la Actividad

# %%
img = Image.open('2017_Brockton_Massachusetts')
plt.imshow(img)
plt.axis('off')
plt.show()

print(f"Objeto: \033[36m{img}\033[0m")
print(f"Formato: \033[36m{img.format}\033[0m")
print(f"Tamaño (Ancho x Alto): \033[36m{img.size}\033[0m")
print(f"Modo de color: \033[36m{img.mode}\033[0m")
# Out:
# Objeto: <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3024x4032 at 0x7B91DE9A1130>
# Formato: JPEG
# Tamaño (Ancho x Alto): (3024, 4032)
# Modo de color: RGB

# %%
img = np.array(img)
alto, ancho, canales = img.shape

print(f"Dimensiones de la imagen: \033[36m{alto}\033[0m píxeles de alto x \033[36m{ancho}\033[0m píxeles de ancho, con \033[36m{canales}\033[0m canales de color.")

pixel_superior_izquierdo = img[0, 0]

print(f"Valor del píxel en (0, 0) [R, G, B]: \033[36m{pixel_superior_izquierdo}\033[0m")
# Out:
# Dimensiones de la imagen: 4032 píxeles de alto x 3024 píxeles de ancho, con 3 canales de color.
# Valor del píxel en (0, 0) [R, G, B]: [249 217 176]

# %%
# Define la ruta completa del archivo a guardar
ruta_completa = os.path.join(ruta_drive, 'img.npy')

# Guarda el array en el archivo .npy dentro de Google Drive
np.save(ruta_completa, img)

print(f"Archivo guardado con éxito en: \033[34m{ruta_completa}\033[0m ✅")
# Out:
# Archivo guardado con éxito en: /content/drive/MyDrive/MNA_Vision/2.5_Algoritmos_Pixeles/img.npy ✅

# %%
original_image = Image.open('2017_Brockton_Massachusetts')
plt.imshow(original_image)
type(original_image)

# Save the image
np.save('img.npy', original_image)

#Load the image
original_image = np.load('img.npy')

# %% [markdown]
# ## Histogram Equalization<a class="anchor" id="hist" ></a>

# %% [markdown]
# Let's look at the distribution of pixel values in the image.
#
# Ideally, the image should have relatively even distribution of values, indicating good contrast and making it easier to extract analytical information.
#
# An easy way to check this is to plot a histogram.

# %%
# Plot a histogram - we need to use ravel to "flatten" the 3 dimensions
plt.hist(original_image.ravel())
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def plot_minimalist_histogram(image_path):
    # Configuración minimalista
    plt.rcParams['figure.facecolor'] = '#f8f9fa'
    plt.rcParams['axes.facecolor'] = '#ffffff'
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial', 'DejaVu Sans']

    # Cargar imagen
    img = Image.open(image_path)
    img_array = np.array(img)

    # Crear figura
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    fig.patch.set_facecolor('#f8f9fa')

    # Configuración de colores suaves
    colors = {
        'R': {'main': '#ff6b6b', 'light': '#ffe0e0'},
        'G': {'main': '#51cf66', 'light': '#d0f4d0'},
        'B': {'main': '#339af0', 'light': '#d0e7ff'}
    }

    titles = ['Canal Rojo', 'Canal Verde', 'Canal Azul']

    for idx, (ax, channel_name, title) in enumerate(zip(axes, ['R', 'G', 'B'], titles)):
        # Obtener datos del canal
        channel_data = img_array[:,:,idx].ravel()

        # Crear histograma con estilo elegante
        n, bins, patches = ax.hist(channel_data, bins=256,
                                   color=colors[channel_name]['light'],
                                   edgecolor=colors[channel_name]['main'],
                                   linewidth=0.5, alpha=0.7)

        # Agregar línea suave de tendencia
        from scipy.ndimage import gaussian_filter1d
        smoothed = gaussian_filter1d(n, sigma=2)
        bin_centers = (bins[:-1] + bins[1:]) / 2
        ax.plot(bin_centers, smoothed, color=colors[channel_name]['main'],
               linewidth=2, alpha=0.9)

        # Estilizar ejes
        ax.set_title(title, fontsize=12, fontweight='600', pad=15)
        ax.set_xlabel('Intensidad', fontsize=10)
        ax.set_ylabel('Frecuencia', fontsize=10)

        # Remover bordes superiores y derechos
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_linewidth(0.5)
        ax.spines['bottom'].set_linewidth(0.5)

        # Grid sutil
        ax.grid(True, alpha=0.1, linestyle='-', linewidth=0.5)
        ax.set_axisbelow(True)

        # Agregar estadística clave de forma sutil
        mean_val = np.mean(channel_data)
        ax.text(0.98, 0.98, f'μ = {mean_val:.1f}',
               transform=ax.transAxes,
               fontsize=10, ha='right', va='top',
               bbox=dict(boxstyle='round,pad=0.3',
                        facecolor='white',
                        edgecolor=colors[channel_name]['main'],
                        alpha=0.8))

    # Título general
    fig.suptitle(f'Análisis de Histograma: {image_path}',
                fontsize=14, fontweight='bold', y=1.05)

    plt.tight_layout()
    plt.show()

# Usar
plot_minimalist_histogram('2017_Brockton_Massachusetts')

# %% [markdown]
# Another useful way to visualize the statistics of an image is as a cumulative distribution function (CDF) plot. Which shows the cumulative pixel intensity frequencies from 0 to 255.

# %%
plt.hist(original_image.ravel(), bins=255, cumulative=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy.ndimage import gaussian_filter1d

def plot_cumulative_histogram_beautiful(image_path):
    # Configuración minimalista
    plt.rcParams['figure.facecolor'] = '#f8f9fa'
    plt.rcParams['axes.facecolor'] = '#ffffff'
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial', 'DejaVu Sans']

    # Cargar imagen
    img = Image.open(image_path)
    img_array = np.array(img)

    # Crear figura con subplots
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.patch.set_facecolor('#f8f9fa')

    # Configuración de colores suaves
    colors = {
        'R': {'main': '#ff6b6b', 'light': '#ffe0e0', 'dark': '#e55555'},
        'G': {'main': '#51cf66', 'light': '#d0f4d0', 'dark': '#40b855'},
        'B': {'main': '#339af0', 'light': '#d0e7ff', 'dark': '#228ae6'},
        'All': {'main': '#868e96', 'light': '#e9ecef', 'dark': '#495057'}
    }

    # ============= SUBPLOT 1: Histograma Acumulativo Combinado =============
    ax1 = axes[0, 0]

    # Datos para todos los canales
    for idx, (channel_name, title) in enumerate(zip(['R', 'G', 'B'],
                                                     ['Rojo', 'Verde', 'Azul'])):
        channel_data = img_array[:,:,idx].ravel()

        # Crear histograma acumulativo
        counts, bins, patches = ax1.hist(channel_data, bins=256,
                                         cumulative=True,
                                         density=True,
                                         histtype='step',
                                         color=colors[channel_name]['main'],
                                         linewidth=2.5,
                                         alpha=0.8,
                                         label=f'Canal {title}')

    ax1.set_title('Distribución Acumulativa RGB', fontsize=13, fontweight='600', pad=15)
    ax1.set_xlabel('Intensidad de Píxel', fontsize=11)
    ax1.set_ylabel('Probabilidad Acumulada', fontsize=11)
    ax1.legend(loc='lower right', frameon=True, fancybox=True, shadow=True)
    ax1.grid(True, alpha=0.15, linestyle='-', linewidth=0.5)
    ax1.set_xlim([0, 255])
    ax1.set_ylim([0, 1.05])

    # Agregar líneas de referencia
    ax1.axhline(y=0.5, color='gray', linestyle='--', alpha=0.3, linewidth=1)
    ax1.axhline(y=0.25, color='gray', linestyle=':', alpha=0.2, linewidth=1)
    ax1.axhline(y=0.75, color='gray', linestyle=':', alpha=0.2, linewidth=1)

    # ============= SUBPLOT 2: Histograma Acumulativo Total (Luminosidad) =============
    ax2 = axes[0, 1]

    # Calcular luminosidad
    luminosity = np.mean(img_array, axis=2).ravel()

    # Histograma acumulativo con relleno
    counts, bins, patches = ax2.hist(luminosity, bins=256,
                                     cumulative=True,
                                     density=True,
                                     color=colors['All']['light'],
                                     edgecolor=colors['All']['dark'],
                                     linewidth=1.5,
                                     alpha=0.7)

    # Línea suavizada
    bin_centers = (bins[:-1] + bins[1:]) / 2
    smoothed = gaussian_filter1d(counts, sigma=1)
    ax2.plot(bin_centers, smoothed, color=colors['All']['dark'],
            linewidth=3, alpha=0.9, label='Curva suavizada')

    # Encontrar percentiles
    percentiles = [25, 50, 75]
    for p in percentiles:
        val = np.percentile(luminosity, p)
        ax2.axvline(x=val, color='red', linestyle='--', alpha=0.5, linewidth=1)
        ax2.text(val, 0.05, f'P{p}', rotation=90, fontsize=9,
                ha='right', va='bottom', color='red', alpha=0.7)

    ax2.set_title('Distribución Acumulativa de Luminosidad', fontsize=13, fontweight='600', pad=15)
    ax2.set_xlabel('Intensidad de Píxel', fontsize=11)
    ax2.set_ylabel('Probabilidad Acumulada', fontsize=11)
    ax2.legend(loc='lower right', frameon=True, fancybox=True, shadow=True)
    ax2.grid(True, alpha=0.15, linestyle='-', linewidth=0.5)
    ax2.set_xlim([0, 255])
    ax2.set_ylim([0, 1.05])

    # ============= SUBPLOTS 3-5: Canales Individuales con Área =============
    channels_data = [
        (img_array[:,:,0].ravel(), 'R', 'Canal Rojo'),
        (img_array[:,:,1].ravel(), 'G', 'Canal Verde'),
        (img_array[:,:,2].ravel(), 'B', 'Canal Azul')
    ]

    for idx, (data, color_key, title) in enumerate(channels_data):
        if idx < 2:
            ax = axes[1, idx]
        else:
            # Usar el último subplot disponible para el canal azul
            ax = plt.subplot2grid((2, 3), (1, 2), colspan=1, fig=fig)

        # Calcular histograma acumulativo
        counts, bins = np.histogram(data, bins=256)
        cumulative = np.cumsum(counts)
        cumulative = cumulative / cumulative[-1]  # Normalizar

        # Plot con relleno gradiente
        bin_centers = (bins[:-1] + bins[1:]) / 2
        ax.fill_between(bin_centers, 0, cumulative,
                       color=colors[color_key]['light'],
                       alpha=0.5)
        ax.plot(bin_centers, cumulative,
               color=colors[color_key]['main'],
               linewidth=2.5, alpha=0.9)

        # Agregar puntos en cuartiles
        quartiles = [25, 50, 75]
        for q in quartiles:
            val = np.percentile(data, q)
            y_val = np.interp(val, bin_centers, cumulative)
            ax.scatter(val, y_val, color=colors[color_key]['dark'],
                      s=50, zorder=5, alpha=0.8)
            ax.annotate(f'{q}%', xy=(val, y_val),
                       xytext=(5, 5), textcoords='offset points',
                       fontsize=9, color=colors[color_key]['dark'],
                       fontweight='bold')

        # Estadísticas
        mean_val = np.mean(data)
        median_val = np.median(data)
        std_val = np.std(data)

        stats_text = f'μ={mean_val:.1f}\nσ={std_val:.1f}'
        ax.text(0.98, 0.05, stats_text,
               transform=ax.transAxes,
               fontsize=10, ha='right', va='bottom',
               bbox=dict(boxstyle='round,pad=0.5',
                        facecolor='white',
                        edgecolor=colors[color_key]['main'],
                        alpha=0.9))

        ax.set_title(title, fontsize=12, fontweight='600', pad=10)
        ax.set_xlabel('Intensidad', fontsize=10)
        ax.set_ylabel('Probabilidad Acumulada', fontsize=10)
        ax.set_xlim([0, 255])
        ax.set_ylim([0, 1.05])

        # Estilo minimalista
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_linewidth(0.5)
        ax.spines['bottom'].set_linewidth(0.5)
        ax.grid(True, alpha=0.1, linestyle='-', linewidth=0.5)
        ax.set_axisbelow(True)

    # Título general
    fig.suptitle(f'📊 Análisis de Distribución Acumulativa: {image_path}',
                fontsize=15, fontweight='bold', y=1.02)

    plt.tight_layout()
    plt.show()

# Usar
plot_cumulative_histogram_beautiful('2017_Brockton_Massachusetts')
# Out:
# /tmp/ipython-input-2870191833.py:169: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# The histogram and CDF for our image show pretty uneven distribution - there's a lot of contrast in the image. Ideally we should equalize the values in the images we want to analyse to try to make our images more consistent in terms of the shapes they contain irrespective of light levels.
#
# Histogram equalization is often used to improve the statistics of images. In simple terms, the histogram equalization algorithm attempts to adjust the pixel values in the image to create a more uniform distribution. The code in the cell below uses the  **exposure.equalize_hist** method from the **skimage** package to equalize the image.

# %%
original_image_eq = exposure.equalize_hist(original_image)

fig = plt.figure(figsize=(16, 8))

# Subplot for original image
a=fig.add_subplot(1,2,1)
imgplot = plt.imshow(original_image)
a.set_title('Before')

# Subplot for processed image
a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(original_image_eq)
a.set_title('After')

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:445: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)

# %% [markdown]
# As with most image operations, there's more than one way to do this. For example, you could also use the **PIL.ImgOps.equalize** method:

# %%
# Equalize the image - but we need to convert the numpy array back to the PIL image format
image_PIL_eq = ImageOps.equalize(Image.fromarray(original_image))

# Display using matplotlib

# Create a figure
fig = plt.figure(figsize=(16, 8))

# Subplot for original image
a=fig.add_subplot(1,2,1)
imgplot = plt.imshow(original_image)
a.set_title('Before')

# Subplot for processed image
a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(image_PIL_eq)
a.set_title('After')

plt.show()

# %% [markdown]
# Now let's see what that's done to the histogram and CDF plots:

# %%
# Display histograms
img_eq = np.array(image_PIL_eq)

# Create a figure
fig = plt.figure(figsize=(16, 8))

# Subplot for original image
a=fig.add_subplot(1,2,1)
imgplot = plt.hist(img_eq.ravel())
a.set_title('Histogram')

# Subplot for processed image
a=fig.add_subplot(1,2,2)
imgplot = plt.hist(img_eq.ravel(), bins=255, cumulative=True)
a.set_title('CDF')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy.ndimage import gaussian_filter1d

# 2. FUNCIÓN PARA CREAR LOS PLOTS
def plot_histogram_vs_cdf_beautiful(image_PIL_eq):
    """
    Crea visualización hermosa de Histograma y CDF
    """
    # Configuración minimalista
    plt.rcParams['figure.facecolor'] = '#f8f9fa'
    plt.rcParams['axes.facecolor'] = '#ffffff'
    plt.rcParams['font.family'] = 'sans-serif'

    # Convertir imagen a array
    img_eq = np.array(image_PIL_eq)
    data = img_eq.ravel()

    # Crear figura
    fig = plt.figure(figsize=(16, 8))
    fig.patch.set_facecolor('#f8f9fa')

    # Colores elegantes
    color_hist = '#3498db'  # Azul suave
    color_cdf = '#e74c3c'   # Rojo suave

    # ================== SUBPLOT 1: HISTOGRAMA ==================
    ax1 = fig.add_subplot(1, 2, 1)

    # Histograma con estilo
    n, bins, patches = ax1.hist(data, bins=256,
                                color='#bdd4e7',
                                edgecolor='#3498db',
                                linewidth=0.5,
                                alpha=0.8)

    # Aplicar gradiente de color a las barras
    for i, patch in enumerate(patches):
        intensity = i / len(patches)
        patch.set_facecolor(plt.cm.Blues(0.3 + intensity * 0.5))

    # Línea suavizada
    smoothed = gaussian_filter1d(n, sigma=2)
    bin_centers = (bins[:-1] + bins[1:]) / 2
    ax1.plot(bin_centers, smoothed, color=color_hist,
            linewidth=2.5, alpha=0.9, label='Tendencia suavizada')

    # Estadísticas
    mean_val = np.mean(data)
    median_val = np.median(data)
    std_val = np.std(data)

    # Líneas de estadísticas
    ax1.axvline(mean_val, color='#2ecc71', linestyle='--',
               linewidth=2, alpha=0.7, label=f'Media: {mean_val:.1f}')
    ax1.axvline(median_val, color='#f39c12', linestyle='--',
               linewidth=2, alpha=0.7, label=f'Mediana: {median_val:.1f}')

    # Configuración del subplot
    ax1.set_title('📊 Histograma', fontsize=14, fontweight='600', pad=15)
    ax1.set_xlabel('Intensidad de Píxel', fontsize=11)
    ax1.set_ylabel('Frecuencia', fontsize=11)
    ax1.legend(loc='upper right')
    ax1.grid(True, alpha=0.15)
    ax1.set_xlim([0, 255])

    # Remover bordes superiores
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)

    # ================== SUBPLOT 2: CDF ==================
    ax2 = fig.add_subplot(1, 2, 2)

    # Calcular y plotear CDF
    n_cdf, bins_cdf, patches_cdf = ax2.hist(data, bins=255,
                                            cumulative=True,
                                            density=True,
                                            histtype='step',
                                            color=color_cdf,
                                            linewidth=2.5,
                                            alpha=0.9)

    # Rellenar área bajo la curva
    ax2.fill_between(bins_cdf[:-1], 0, n_cdf,
                    alpha=0.2, color=color_cdf)

    # Marcar percentiles
    percentiles = [25, 50, 75]
    colors_p = ['#9b59b6', '#2ecc71', '#f39c12']

    for p, color_p in zip(percentiles, colors_p):
        val = np.percentile(data, p)
        y_val = p / 100

        ax2.axhline(y=y_val, color=color_p, linestyle=':',
                   alpha=0.3, linewidth=1)
        ax2.axvline(x=val, color=color_p, linestyle=':',
                   alpha=0.3, linewidth=1)

        ax2.scatter(val, y_val, color=color_p, s=60,
                   zorder=5, alpha=0.8, edgecolor='white', linewidth=2)

        ax2.annotate(f'P{p}', xy=(val, y_val),
                    xytext=(8, 8), textcoords='offset points',
                    fontsize=9, color=color_p, fontweight='bold')

    # Configuración del subplot
    ax2.set_title('📈 CDF (Distribución Acumulativa)',
                 fontsize=14, fontweight='600', pad=15)
    ax2.set_xlabel('Intensidad de Píxel', fontsize=11)
    ax2.set_ylabel('Probabilidad Acumulada', fontsize=11)
    ax2.set_xlim([0, 255])
    ax2.set_ylim([0, 1.05])
    ax2.grid(True, alpha=0.15)

    # Remover bordes superiores
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)

    # Título general
    fig.suptitle('🎨 Análisis de Distribución - Imagen Ecualizada',
                fontsize=16, fontweight='bold', y=0.98)

    plt.tight_layout()
    plt.show()  # ¡IMPORTANTE! Esto muestra el plot

# 3. EJECUTAR LA FUNCIÓN
plot_histogram_vs_cdf_beautiful(image_PIL_eq)
# Out:
# /tmp/ipython-input-3241433385.py:132: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3241433385.py:132: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3241433385.py:132: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# The pixel intensities are more evenly distributed in the equalized image. In particular, the cumulative density shows a straight diagonal cumulation; which is a good sign that the pixel intensity values have been equalized.

# %% [markdown]
# ## Denoising with Filters <a class="anchor" id="denoising" ></a>
#
# Often images need to be cleaned up to remove "salt and pepper" noise.

# %% [markdown]
# ### Add Some Random Noise
# Let's add some random noise to our image - such as you might see in a photograph taken in low light or at a low resolution.

# %%
img_n = skimage.util.random_noise(original_image)
plt.imshow(img_n)

# %% [markdown]
# ### Using a Gaussian Filter
# A Gaussian filter applies a weighted average (mean) value for pixels based on the pixels that surround them.

# %%
img3_gauss = gauss(img_n, sigma=1)
plt.imshow(img3_gauss)

# %% [markdown]
# ### Using a Median Filter
# The Gaussian filter results in a blurred image, which may actually be better for feature extraction as it makes it easier to find contrasting areas. If it's too blurred, we could try a median filter, which as the name suggests applies the median value to pixels based on the pixels around them.

# %%
img_med = med(img_n, size=2)
plt.imshow(img_med)

# %% [markdown]
# ## Challenge <a class="anchor" id="challenge" ></a>
#
# Now, try solving this challenge, you must equalize different windows of the same image in a splitted way.

# %% [markdown]
# ### Challegne Libraries

# %%
# Opción 1: Importar las funciones específicas (nombres correctos)
from image_slicer import join_image, slice_image

# Opción 2: Importar todo el módulo
import image_slicer
# Usar: image_slicer.slice_image() y image_slicer.join_image()

# Opción 3: Importar las clases
from image_slicer import ImageSlicer, ImageJoiner

# %%
# PASO 1: Ver qué archivo tenemos
print("📁 Buscando tu imagen...")
archivo_original = None

# Buscar el archivo con cualquier extensión
for ext in ['.jpeg', '.jpg', '.png', '']:
    nombre = f'2017_Brockton_Massachusetts{ext}'
    if os.path.exists(nombre):
        archivo_original = nombre
        print(f"✅ Encontrado: {archivo_original}")
        break

if not archivo_original:
    print("❌ No se encontró la imagen")
else:
    # PASO 2: Dividir la imagen
    img = Image.open(archivo_original)
    width, height = img.size

    print(f"\n✂️ Dividiendo imagen de {width}x{height} en 4 partes...")

    # Crear los 4 tiles
    for fila in range(2):
        for col in range(2):
            # Calcular coordenadas
            x1 = col * width // 2
            y1 = fila * height // 2
            x2 = (col + 1) * width // 2
            y2 = (fila + 1) * height // 2

            # Cortar y guardar
            tile = img.crop((x1, y1, x2, y2))
            nombre_tile = f'2017_Brockton_Massachusetts_{fila+1:02d}_{col+1:02d}.png'
            tile.save(nombre_tile)
            print(f"  ✓ {nombre_tile}")

    # PASO 3: Verificar resultados
    print("\n📋 ARCHIVOS CREADOS:")
    print("-" * 50)

    for f in sorted(os.listdir('.')):
        if '2017_Brockton_Massachusetts_' in f and f.endswith('.png'):
            if '01_01' in f:
                print(f"{f} → Superior Izquierda")
            elif '01_02' in f:
                print(f"{f} → Superior Derecha")
            elif '02_01' in f:
                print(f"{f} → Inferior Izquierda")
            elif '02_02' in f:
                print(f"{f} → Inferior Derecha")
# Out:
# 📁 Buscando tu imagen...
# ✅ Encontrado: 2017_Brockton_Massachusetts
#
# ✂️ Dividiendo imagen de 3024x4032 en 4 partes...
#   ✓ 2017_Brockton_Massachusetts_01_01.png
#   ✓ 2017_Brockton_Massachusetts_01_02.png
#   ✓ 2017_Brockton_Massachusetts_02_01.png
#   ✓ 2017_Brockton_Massachusetts_02_02.png
#
# 📋 ARCHIVOS CREADOS:
# --------------------------------------------------
# 2017_Brockton_Massachusetts_01_01.png → Superior Izquierda
# 2017_Brockton_Massachusetts_01_02.png → Superior Derecha
# 2017_Brockton_Massachusetts_02_01.png → Inferior Izquierda
# 2017_Brockton_Massachusetts_02_02.png → Inferior Derecha

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(2,2,1)
img = Image.open(f'2017_Brockton_Massachusetts_01_01.png')
plt.imshow(img)

plt.subplot(2,2,2)
img = Image.open(f'2017_Brockton_Massachusetts_01_02.png')
plt.imshow(img)

plt.subplot(2,2,3)
img = Image.open(f'2017_Brockton_Massachusetts_02_01.png')
plt.imshow(img)

plt.subplot(2,2,4)
img = Image.open(f'2017_Brockton_Massachusetts_02_02.png')
plt.imshow(img)

plt.show()

# %% [markdown]
# <img src="https://iili.io/KId98Rp.png" alt="Imagen en alta resolución" width="2500"/>

# %% [markdown]
# <div align="center">
#
# # 🖼️ **Tile-based Histogram Equalization**
#
# <img src="https://img.shields.io/badge/Image%20Processing-Advanced%20Technique-blueviolet?style=for-the-badge&logo=adobe&logoColor=white" alt="Badge">
# <img src="https://img.shields.io/badge/Method-Adaptive%20Enhancement-green?style=for-the-badge&logo=opencv&logoColor=white" alt="Badge">
#
# </div>
#
# ---
#
# > ### 📌 **Definición**
# > **El método de ecualización del histograma basado en mosaicos** es una técnica avanzada de procesamiento digital de imágenes que mejora el contraste de manera ***local y adaptativa***, dividiendo la imagen en regiones para un tratamiento individualizado.
#
# ---
#
# ## 📋 **Proceso de Implementación**
#
# | **Paso** | **Proceso** | **Descripción** |
# |:---:|:---|:---|
# | <kbd>**1**</kbd> | **🔲 División de la imagen** | La imagen se particiona en múltiples mosaicos o tiles de tamaño uniforme |
# | <kbd>**2**</kbd> | **📊 Cálculo individual** | Se computa la ecualización del histograma para cada mosaico de forma independiente |
# | <kbd>**3**</kbd> | **🎯 Aplicación local** | Cada región recibe su propia transformación de intensidad optimizada |
#
# ---
#
# ## ⚖️ **Análisis Comparativo**
#
# <table>
# <tr>
# <td width="50%">
#
# ### ✅ **VENTAJAS**
#
# **1️⃣ Procesamiento localizado**
# `►` Calcula la ecualización de histograma en secciones distintas
# `►` Preserva características locales importantes
#
# **2️⃣ Preservación de bordes**
# `►` Mantiene la definición de bordes en diferentes regiones
# `►` Evita la pérdida de detalles estructurales
#
# **3️⃣ Mejora adaptativa**
# `►` Optimiza el contraste de manera local
# `►` Se adapta a las características de cada región
#
# </td>
# <td width="50%">
#
# ### ❌ **DESVENTAJAS**
#
# **1️⃣ Amplificación de ruido**
# `►` Sobreamplifica el ruido en regiones homogéneas
# `►` Problema cuando el histograma está muy concentrado
#
# **2️⃣ Artefactos visuales**
# `►` Diferencias de contraste entre mosaicos adyacentes
# `►` Puede crear efectos de "patchwork" no deseados
#
# **3️⃣ Costo computacional**
# `►` Mayor tiempo de procesamiento
# `►` Requiere múltiples ecualizaciones independientes
#
# </td>
# </tr>
# </table>
#
# ---
#
# ## 💡 **Conclusión**
#
# <blockquote>
#
# ### **¿Cuándo es superior al método tradicional?**
#
# El método de **`Tile-based Histogram Equalization`** supera al método tradicional cuando se procesan:
#
# - 🌓 Imágenes con regiones de brillo **extremadamente variable**
# - 🏙️ Escenas con áreas muy oscuras **Y** muy brillantes simultáneamente
# - 🔬 Imágenes complejas con **múltiples regiones de interés**
#
# ### **⚠️ Consideraciones importantes:**
#
# - **Precaución:** En imágenes con grandes áreas uniformes, la amplificación del ruido puede degradar la calidad visual
# - **Factor crítico:** La elección del tamaño de los mosaicos es crucial para balancear el mejoramiento local con la coherencia global
#
# </blockquote>
#
# ---
#
# ## 📊 **Comparación Visual de Métodos**
#
# | **Característica** | **Ecualización Global** | **Ecualización por Tiles** | **Mejor para** |
# |:---|:---:|:---:|:---|
# | **Preservación de detalles locales** | ❌ Baja | ✅ Alta | Imágenes médicas |
# | **Velocidad de procesamiento** | ✅ Rápida | ⚠️ Moderada | Procesamiento en tiempo real |
# | **Control de ruido** | ✅ Bueno | ❌ Variable | Imágenes con ruido |
# | **Adaptabilidad** | ❌ Nula | ✅ Excelente | Escenas complejas |
# | **Coherencia global** | ✅ Alta | ⚠️ Media | Fotografía artística |
#
# ---
#
# ## 🔧 **Parámetros Configurables**
#
# <table>
# <tr>
# <td>
#
# **📏 Tamaño del Tile**
# - `8×8` → Mayor detalle local
# - `16×16` → Balance estándar
# - `32×32` → Mayor coherencia
#
# </td>
# <td>
#
# **🎚️ Clip Limit**
# - `0.01` → Mínima mejora
# - `0.03` → Valor típico
# - `0.1` → Mejora agresiva
#
# </td>
# <td>
#
# **📐 Distribución**
# - `uniform` → Todas las intensidades iguales
# - `rayleigh` → Realce de bordes
# - `exponential` → Alto contraste
#
# </td>
# </tr>
# </table>
#
# ---
#
# ## 📚 **Referencias**
#
# > **📖 Fuente Principal:**
# > GeeksforGeeks. (2021, November 22). *Adaptive histogram equalization in image processing using MATLAB*
# > 🔗 **[Ver artículo completo](https://www.geeksforgeeks.org/adaptive-histogram-equalization-in-image-processing-using-matlab/)**
#
# ---
#
# <div align="center">
#
# ### 🏷️ **Tags Relacionados**
#
# <img src="https://img.shields.io/badge/CLAHE-Contrast%20Limited-orange?style=flat-square" alt="CLAHE">
# <img src="https://img.shields.io/badge/AHE-Adaptive%20HE-blue?style=flat-square" alt="AHE">
# <img src="https://img.shields.io/badge/Image-Enhancement-green?style=flat-square" alt="Enhancement">
# <img src="https://img.shields.io/badge/Local-Processing-purple?style=flat-square" alt="Local">
# <img src="https://img.shields.io/badge/MATLAB-Compatible-red?style=flat-square" alt="MATLAB">
#
# </div>

# %%
# PASO 1: Abrir los 4 tiles
print("Abriendo tiles...")
tile1 = Image.open('2017_Brockton_Massachusetts_01_01.png')
tile2 = Image.open('2017_Brockton_Massachusetts_01_02.png')
tile3 = Image.open('2017_Brockton_Massachusetts_02_01.png')
tile4 = Image.open('2017_Brockton_Massachusetts_02_02.png')

# PASO 2: Crear imagen unida
w, h = tile1.size
new_image = Image.new('RGB', (w*2, h*2))

# PASO 3: Pegar cada tile en su lugar
new_image.paste(tile1, (0, 0))    # Superior izquierda
new_image.paste(tile2, (w, 0))    # Superior derecha
new_image.paste(tile3, (0, h))    # Inferior izquierda
new_image.paste(tile4, (w, h))    # Inferior derecha

# PASO 4: Mostrar con matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(new_image)
plt.title('Imagen Unida')
plt.axis('off')
plt.show()

print("✅ Imagen unida y mostrada exitosamente")
# Out:
# Abriendo tiles...
# ✅ Imagen unida y mostrada exitosamente

# %% [markdown]
# Empleando el método dir(), podemos ver que se puede acceder a la imagen de los mosaicos con: tiles[0].image, tiles[1].image, etc.
#
# Por lo tanto, se puede equalizar cada mosaico de manera individual y luego unir los mosaicos ecualizados

# %%
# ECUALIZACIÓN DE HISTOGRAMA EN TILES

# PASO 1: Cargar los tiles desde archivos
print("📌 Cargando y ecualizando tiles...")

tiles_originales = []
tiles_ecualizados = []

# Cargar cada tile y aplicar ecualización
for row in range(1, 3):
    for col in range(1, 3):
        filename = f'2017_Brockton_Massachusetts_{row:02d}_{col:02d}.png'

        # Abrir tile original
        tile = Image.open(filename)
        tiles_originales.append(tile)

        # Aplicar ecualización de histograma
        tile_eq = ImageOps.equalize(tile.convert('RGB'))
        tiles_ecualizados.append(tile_eq)

        # Guardar tile ecualizado (opcional)
        tile_eq.save(f'tile_{row:02d}_{col:02d}_equalized.png')
        print(f"  ✓ Ecualizado: {filename}")

# PASO 2: Unir tiles ecualizados
print("\n🔗 Uniendo tiles ecualizados...")

w, h = tiles_ecualizados[0].size
imagen_ecualizada = Image.new('RGB', (w*2, h*2))

# Pegar cada tile en su posición
imagen_ecualizada.paste(tiles_ecualizados[0], (0, 0))    # 01_01
imagen_ecualizada.paste(tiles_ecualizados[1], (w, 0))    # 01_02
imagen_ecualizada.paste(tiles_ecualizados[2], (0, h))    # 02_01
imagen_ecualizada.paste(tiles_ecualizados[3], (w, h))    # 02_02

# PASO 3: Mostrar resultado
plt.figure(figsize=(10, 10))
plt.imshow(imagen_ecualizada)
plt.title('Imagen con Ecualización de Histograma')
plt.axis('off')
plt.show()

print("✅ Ecualización completada")
# Out:
# 📌 Cargando y ecualizando tiles...
#   ✓ Ecualizado: 2017_Brockton_Massachusetts_01_01.png
#   ✓ Ecualizado: 2017_Brockton_Massachusetts_01_02.png
#   ✓ Ecualizado: 2017_Brockton_Massachusetts_02_01.png
#   ✓ Ecualizado: 2017_Brockton_Massachusetts_02_02.png
#
# 🔗 Uniendo tiles ecualizados...
# ✅ Ecualización completada

# %% [markdown]
# ### Si creamos una función para dividir la imagen en "n" mosaicos, equalizarlos y unirlos nuevamente, podemos experimentar con diferentes valores

# %%
import math

def procesar_imagen_por_bloques(img_path: str, n_divisiones: int) -> Image.Image:
    """
    Divide una imagen en 'n' bloques, ecualiza el histograma de cada bloque
    individualmente y luego los une para formar una nueva imagen.

    Args:
        img_path (str): La ruta a la imagen de entrada.
        n_divisiones (int): El número de bloques en los que se dividirá la imagen.

    Returns:
        Image.Image: La imagen procesada con ecualización adaptativa.
    """
    try:
        img = Image.open(img_path).convert('RGB')
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo en la ruta '{img_path}'")
        return None

    w, h = img.size

    # Si n <= 1, se realiza una ecualización global simple.
    if n_divisiones <= 1:
        return ImageOps.equalize(img)

    # Busca los factores de n_divisiones más cercanos a su raíz cuadrada
    # para que la cuadrícula sea lo más "cuadrada" posible.
    # Esto funciona para cualquier número, no solo para cuadrados perfectos (4, 9, 16...).
    cols = int(math.sqrt(n_divisiones))
    while n_divisiones % cols != 0:
        cols -= 1
    rows = n_divisiones // cols

    tile_w = w // cols
    tile_h = h // rows

    tiles = []
    # Itera sobre las filas y columnas para procesar cada bloque
    for r in range(rows):
        for c in range(cols):
            # Define la caja de recorte para el bloque actual
            box = (c * tile_w, r * tile_h, (c + 1) * tile_w, (r + 1) * tile_h)
            tile = img.crop(box)

            # Ecualiza el bloque y lo añade a la lista
            tile_eq = ImageOps.equalize(tile)
            tiles.append(tile_eq)

    # Crea una nueva imagen en blanco para pegar los bloques procesados
    new_img = Image.new('RGB', (w, h))

    # Itera sobre los bloques procesados y los pega en su posición correcta
    for i, tile in enumerate(tiles):
        r = i // cols
        c = i % cols
        new_img.paste(tile, (c * tile_w, r * tile_h))

    return new_img

# --- SCRIPT DE VISUALIZACIÓN ---

# Configuración
ruta_imagen = '2017_Brockton_Massachusetts'
divisiones_a_probar = [2, 4, 6, 9, 20]

# Crea una figura y un conjunto de subplots (ejes) en una sola fila
fig, axes = plt.subplots(1, len(divisiones_a_probar), figsize=(20, 5))

# Título principal para toda la figura
fig.suptitle('Comparación de Ecualización Adaptativa por Bloques', fontsize=18)

# Itera sobre la lista de divisiones y los ejes para procesar y mostrar cada imagen
for ax, n in zip(axes, divisiones_a_probar):
    imagen_procesada = procesar_imagen_por_bloques(ruta_imagen, n)

    if imagen_procesada:
        ax.imshow(imagen_procesada)
        ax.set_title(f'{n} Divisiones') # Añade el título a cada imagen
        ax.axis('off') # Oculta los ejes para un look más limpio

# Ajusta el espaciado para que no se solapen los títulos y muestra la figura
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### En el caso de esta fotografía, funcionó mejor dividirla en 2 porque principalmente la mitad izquierda es la que está subexpuesta.

# %% [markdown]
# ### Ahora cargamos una imagen en escala de grises para ver cómo funciona la equalización de histrogramas en escala de grises

# %%
import cv2

original_image_gray = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

plt.imshow(original_image_gray, cmap = 'gray')

# %%
original_image_gray_eq = cv2.equalizeHist(original_image_gray)

fig = plt.figure(figsize=(16, 8))

# Subplot for original image
a=fig.add_subplot(1,2,1)
imgplot = plt.imshow(original_image_gray, cmap='gray')
a.set_title('Before')

# Subplot for processed image
a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(original_image_gray_eq, cmap='gray')
a.set_title('After')

plt.show()

# %%
# Crear imagen gris y dividir
original_image_gray_pil = Image.fromarray(original_image_gray)
img = original_image_gray_pil
w, h = img.size

# Crear directorio
os.makedirs('content/data', exist_ok=True)

# Dividir, guardar y mostrar
fig, axes = plt.subplots(2, 2, figsize=(10, 6))
positions = [(0,0), (1,0), (0,1), (1,1)]

for idx, (r, c) in enumerate(positions):
    # Coordenadas del tile
    x1, y1 = c * w//2, r * h//2
    x2, y2 = (c+1) * w//2, (r+1) * h//2

    # Cortar y guardar
    tile = img.crop((x1, y1, x2, y2))
    filename = f'content/data/2017_Brockton_Massachusetts_gray_{r+1:02d}_{c+1:02d}.jpeg'
    tile.save(filename)

    # Mostrar
    axes[r, c].imshow(tile, cmap='gray')
    axes[r, c].set_title(f'Tile {r+1:02d}_{c+1:02d}')
    axes[r, c].axis('off')

plt.tight_layout()
plt.show()

# %%
# Abrir y dividir imagen
img = Image.open('2017_Brockton_Massachusetts_gray.jpeg')
w, h = img.size

# Dividir en 4 tiles
tiles = [
    img.crop((0, 0, w//2, h//2)),
    img.crop((w//2, 0, w, h//2)),
    img.crop((0, h//2, w//2, h)),
    img.crop((w//2, h//2, w, h))
]

# Ecualizar cada tile
tiles_eq = [Image.fromarray(cv2.equalizeHist(np.array(t))) for t in tiles]

# Unir tiles
result = Image.new('L', (w, h))
result.paste(tiles_eq[0], (0, 0))
result.paste(tiles_eq[1], (w//2, 0))
result.paste(tiles_eq[2], (0, h//2))
result.paste(tiles_eq[3], (w//2, h//2))

plt.imshow(result, cmap='gray')
plt.show()

# %% [markdown]
# Definimos, para escala de grises, la función que divide la imagen en "n" mosaicos, los equaliza y une nuevamente, para experimentar con diferentes valores

# %%
def procesar_gris_por_bloques(img_path: str, n_divisiones: int) -> Image.Image:
    """
    Divide una imagen en escala de grises en 'n' bloques, ecualiza el
    histograma de cada bloque con cv2.equalizeHist y los une de nuevo.

    Args:
        img_path (str): La ruta a la imagen de entrada.
        n_divisiones (int): El número de bloques en los que se dividirá.

    Returns:
        Image.Image: La imagen procesada en escala de grises.
    """
    try:
        # Abrir la imagen directamente en escala de grises ('L' mode)
        img = Image.open(img_path).convert('L')
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo en la ruta '{img_path}'")
        return None

    w, h = img.size

    if n_divisiones <= 1:
        # Ecualización global para el caso base
        img_np = np.array(img)
        img_eq_np = cv2.equalizeHist(img_np)
        return Image.fromarray(img_eq_np)

    # Calcular filas y columnas para que la cuadrícula sea lo más cuadrada posible
    cols = int(math.sqrt(n_divisiones))
    while n_divisiones % cols != 0:
        cols -= 1
    rows = n_divisiones // cols

    tile_w = w // cols
    tile_h = h // rows

    # Crea una imagen en blanco para pegar los resultados
    new_img = Image.new('L', (w, h))

    # Itera sobre las filas y columnas para procesar cada bloque
    for r in range(rows):
        for c in range(cols):
            # Recorta el bloque (tile)
            box = (c * tile_w, r * tile_h, (c + 1) * tile_w, (r + 1) * tile_h)
            tile = img.crop(box)

            # Procesa el bloque: PIL -> NumPy -> equalizeHist -> PIL
            tile_np = np.array(tile)
            tile_eq_np = cv2.equalizeHist(tile_np)
            tile_eq = Image.fromarray(tile_eq_np)

            # Pega el bloque procesado en la nueva imagen
            new_img.paste(tile_eq, box)

    return new_img

# --- SCRIPT DE VISUALIZACIÓN ---

# Configuración
ruta_imagen = '2017_Brockton_Massachusetts_gray.jpeg'
divisiones_a_probar = [2, 4, 6, 9, 20] # Valores que solicitaste

# Crea una figura y un conjunto de subplots en una fila horizontal
fig, axes = plt.subplots(1, len(divisiones_a_probar), figsize=(25, 5))

fig.suptitle('Comparación de Ecualización por Bloques (Escala de Grises)', fontsize=18)

# Itera para procesar y mostrar cada imagen
for ax, n in zip(axes, divisiones_a_probar):
    imagen_procesada = procesar_gris_por_bloques(ruta_imagen, n)

    if imagen_procesada:
        # Muestra la imagen. Es CRÍTICO usar cmap='gray' para verla correctamente.
        ax.imshow(imagen_procesada, cmap='gray')
        ax.set_title(f'{n} Divisiones')
        ax.axis('off')

# Ajusta el espaciado y muestra la figura final
plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %% [markdown]
# En el caso de esta fotografía, funcionó mejor dividirla en 2 porque principalmente la mitad izquierda es la que está subexpuesta.
